# %% [markdown]
# # Packages

# %%
# Visualisation
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns
from pyvis.network import Network

# Data analysis / Data processing
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth', None)
pd.options.display.float_format = "{:,.4f}".format
from datetime import time, timedelta, datetime
import numpy as np
import networkx as nx
from collections import defaultdict
import ast
import json

# Maths & Stats
import math 
import scipy.stats as st
from scipy import stats
from scipy.stats import norm
import statsmodels.stats.weightstats as ws
from statsmodels.stats.proportion import test_proportions_2indep
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
# from ambrosia.designer import Designer
# from ambrosia.tester import Tester
import expab
from sklearn.linear_model import Ridge
import random
from sklearn.metrics import mean_absolute_error, mean_squared_error
import AB_library
# from ambrosia.designer import Designer
# from ambrosia.tester import Tester
from statsmodels.stats.power import NormalIndPower
from statsmodels.stats.proportion import proportion_effectsize
from math import ceil


# System library
import os
import ipywidgets
import warnings
warnings.filterwarnings('ignore')
from tqdm.notebook import tqdm
tqdm.pandas()
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# %config InlineBackend.figure_format='retina'
# from itables import init_notebook_mode
# init_notebook_mode(all_interactive=True)
import openpyxl

# Data connection
from google.cloud import bigquery
bigquery_client = bigquery.Client(project='analytics-dev-333113')


# Useful functions
def read_bq(query, project='analytics-dev-333113'):
    client = bigquery.Client(project=project)
    query_job = client.query(query)
    result_df = query_job.to_dataframe()
    return result_df

def display_side_by_side(*args):

    html_str = ''
    for df in args:
        html_str += df.to_html()
    display_html(
        html_str.replace('table','table style="display:inline"'), 
        raw=True
    )

def cycle_sql(start, end, query, weeks=False):
    """
    You have to use {date} in your script to add cycle date into this backets
    """
    date_start = datetime.strptime(start, '%Y-%m-%d')
    date_end = datetime.strptime(end, '%Y-%m-%d')

    if weeks == False:
        daterange = [(date_start + timedelta(days=x)).strftime('%Y-%m-%d') for x in range(((date_end-date_start).days)+1)]
    else:
        daterange = [(date_start + timedelta(weeks=x)).strftime('%Y-%m-%d') for x in range(((date_end-date_start).days//7)+1)] # weeks dividing days by 7

    total_df = pd.DataFrame()

    counter = 0

    for date in daterange:
        counter+=1
        print(f"{counter}) Uploading - {date}:", datetime.today().strftime('%Y-%m-%d %H:%M:%S'))
        script = query.format(date = date)
        df_cycle = bigquery_client.query(script).to_dataframe()
        if df_cycle.empty == True:
            print('Dataframe is empty')
        total_df = pd.concat([df_cycle, total_df])
    return total_df  

def writing_excel(name:str, dataset1=None, dataset2=None, dataset3=None, dataset4=None):
    with pd.ExcelWriter(f"{name}.xlsx") as writer:

    # use to_excel function and specify the sheet_name and index 
    # to store the dataframe in specified sheet

        if dataset1 is not None:
            if dataset2 is not None:
                if dataset3 is not None:
                    if dataset4 is not None:
                        dataset1.to_excel(writer, sheet_name=f"1-{name}", 
                                        #   index=False
                                            )
                        dataset2.to_excel(writer, sheet_name=f"2-{name}", 
                                        #   index=False
                                            )
                        dataset3.to_excel(writer, sheet_name=f"3-{name}", 
                                        #   index=False
                                            )
                        dataset4.to_excel(writer, sheet_name=f"4-{name}", 
                                        #   index=False
                                            )
                    else:
                        dataset1.to_excel(writer, sheet_name=f"1-{name}", 
                                        #   index=False
                                            )
                        dataset2.to_excel(writer, sheet_name=f"2-{name}", 
                                        #   index=False
                                            )
                        dataset3.to_excel(writer, sheet_name=f"3-{name}", 
                                        #   index=False
                                            )
                else:
                    dataset1.to_excel(writer, sheet_name=f"1-{name}", 
                                    #   index=False
                                        )
                    dataset2.to_excel(writer, sheet_name=f"2-{name}", 
                                    #   index=False
                                        )
            else:
                dataset1.to_excel(writer, sheet_name=f"1-{name}", 
                                #   index=False
                                    )

        print('DataFrame is written to Excel File successfully.')
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# # Analysis

# %%
df = read_bq("""
WITH complaints AS (SELECT name,
                           user_id,
                           JSON_EXTRACT(payload, '$.tags') AS tags,
                           JSON_EXTRACT(payload, '$.text') AS text,
                           payload,
                           client_time_ts,
                           order_uuid
                    FROM indriver-e6e40.emart.product_event
                    WHERE name IN ('client.driver_feed_complaint.show',
                                   'client.driver_feed_complaint.click')
                      AND event_dt_part >= '2025-10-13'),
     incidents AS (SELECT redmine_id,
                          incident_date,
                          order_timestamp AS incident_ts,
                          driver_id,
                          pass_id         AS aggressor_id,
                          category,
                          incident_level,
                          information_status
                   FROM indriver-bi.safety.vw_safety_incidents_detail
                   WHERE 1 = 1
                     AND aggressor = 'Passenger'
                     AND incident_date >= '2025-10-10'
                   QUALIFY ROW_NUMBER() OVER (PARTITION BY pass_id ORDER BY incident_date DESC) = 1),
     orders AS (SELECT user_id AS pass_id, driver_id, order_uuid, order_id, order_timestamp
                FROM indriver-e6e40.emart.incity_detail
                WHERE created_date_order_part >= '2025-10-10'
                UNION ALL
                SELECT user_id AS pass_id, driver_id, order_uuid, order_id, order_timestamp
                FROM indriver-e6e40.emart.intercity_detail
                WHERE created_date_order_part >= '2025-10-10'
                UNION ALL
                SELECT user_id AS pass_id, driver_id, order_uuid, order_id, order_timestamp
                FROM indriver-e6e40.emart.delivery_detail
                WHERE created_date_order_part >= '2025-10-10')
SELECT *
FROM complaints t1
         JOIN orders t2 ON t1.order_uuid = t2.order_uuid AND t1.user_id = t2.driver_id
         LEFT JOIN incidents t3 ON t2.pass_id = t3.aggressor_id AND t3.incident_ts > t2.order_timestamp
             """)

df.head()
# Out:
#                                  name    user_id                                            tags text                                                                                                                                                                                                               payload            client_time_ts                            order_uuid    pass_id  driver_id                          order_uuid_1             order_id           order_timestamp redmine_id incident_date incident_ts  driver_id_1  aggressor_id category incident_level information_status
# 0  client.driver_feed_complaint.click   52351915                     "[\"suspicious_activity\"]"   ""                      {"appsflyer_device_id":"1671345840397-2386201557952562867","city_id":"4193","order_id":"0199e518-24fc-800c-c050-ce60c0a32959","tags":"[\"suspicious_activity\"]","text":"","user_id":"52351915"} 2025-10-14 23:41:57+00:00  0199e518-24fc-800c-c050-ce60c0a32959   14289337   52351915  0199e518-24fc-800c-c050-ce60c0a32959  2523204211556775479 2025-10-14 17:39:48+00:00       None           NaT         NaT         <NA>          <NA>     None           None               None
# 1  client.driver_feed_complaint.click  218384160                               "[\"low_price\"]"   ""                               {"appsflyer_device_id":"1739291837539-6039739127279417428","city_id":"4143","order_id":"0199e381-d114-800c-c07f-05613e23f7e8","tags":"[\"low_price\"]","text":"","user_id":"218384160"} 2025-10-14 16:17:37+00:00  0199e381-d114-800c-c07f-05613e23f7e8  292419497  218384160  0199e381-d114-800c-c07f-05613e23f7e8  1238885464189313317 2025-10-14 10:15:59+00:00       None           NaT         NaT         <NA>          <NA>     None           None               None
# 2  client.driver_feed_complaint.click  119422529                               "[\"low_price\"]"   ""                               {"appsflyer_device_id":"1757685057344-7702484499022102842","city_id":"5448","order_id":"0199e1f6-6a72-803c-c074-144d197b7b35","tags":"[\"low_price\"]","text":"","user_id":"119422529"} 2025-10-14 09:06:04+00:00  0199e1f6-6a72-803c-c074-144d197b7b35  300311853  119422529  0199e1f6-6a72-803c-c074-144d197b7b35  2179732976460348726 2025-10-14 14:04:06+00:00       None           NaT         NaT         <NA>          <NA>     None           None               None
# 3  client.driver_feed_complaint.click  176525247  "[\"sexual_content\",\"suspicious_activity\"]"   ""  {"appsflyer_device_id":"1749733543451-6918949578580495983","city_id":"4194","order_id":"0199e509-e451-800c-c06f-ae52837acd73","tags":"[\"sexual_content\",\"suspicious_activity\"]","text":"","user_id":"176525247"} 2025-10-14 22:27:14+00:00  0199e509-e451-800c-c06f-ae52837acd73   14621968  176525247  0199e509-e451-800c-c06f-ae52837acd73  1209781689953842903 2025-10-14 17:24:14+00:00       None           NaT         NaT         <NA>          <NA>     None           None               None
# 4  client.driver_feed_complaint.click  159495584                               "[\"low_price\"]"   ""                               {"appsflyer_device_id":"1757368179023-6631326609715579276","city_id":"4255","order_id":"0199e35a-1903-8016-c053-4ce75e488064","tags":"[\"low_price\"]","text":"","user_id":"159495584"} 2025-10-14 15:37:01+00:00  0199e35a-1903-8016-c053-4ce75e488064  281535936  159495584  0199e35a-1903-8016-c053-4ce75e488064  9153992113728156417 2025-10-14 10:32:36+00:00       None           NaT         NaT         <NA>          <NA>     None           None               None

# %%
def extract_tags_list(json_str):
    if pd.isna(json_str) or json_str is None:
        return None
    try:
        return json.loads(json_str)
    except json.JSONDecodeError:
        return None


def safe_literal_eval(val):

    if pd.isna(val) or not isinstance(val, str):
        return []
    
    try:
        return ast.literal_eval(val) if val.startswith('[') and val.endswith(']') else [val]
    except (ValueError, SyntaxError):
        return [val]
    


df['tags_list'] = df['tags'].apply(extract_tags_list)
df['tags_list'] = df['tags_list'].apply(safe_literal_eval)

df_res = df[['pass_id', 'driver_id', 'tags_list', 'text', 'redmine_id', 'category', 'incident_level']]

df_res
# Out:
#          pass_id  driver_id                              tags_list text redmine_id category incident_level
# 0       14289337   52351915                  [suspicious_activity]   ""       None     None           None
# 1      292419497  218384160                            [low_price]   ""       None     None           None
# 2      300311853  119422529                            [low_price]   ""       None     None           None
# 3       14621968  176525247  [sexual_content, suspicious_activity]   ""       None     None           None
# 4      281535936  159495584                            [low_price]   ""       None     None           None
# ...          ...        ...                                    ...  ...        ...      ...            ...
# 72327  116004036  220237551                                [drugs]   ""       None     None           None
# 72328  138739862  278574417                            [low_price]   ""       None     None           None
# 72329   50141575  202138167             [long_distance, low_price]   ""       None     None           None
# 72330   48400140  253678349             [low_price, long_distance]   ""       None     None           None
# 72331  318637972  233855716             [long_distance, low_price]   ""       None     None           None
#
# [72332 rows x 7 columns]

# %%
df_res_1 = df_res.groupby('pass_id', as_index=False)['driver_id'].count()

df_res_2 = df_res_1.merge(df_res[['pass_id', 'redmine_id']].drop_duplicates(), on='pass_id', how='left')

df_me = df_res_2.groupby('driver_id', as_index=False)[['pass_id', 'redmine_id']].nunique()

df_me = df_me.rename(columns={
    'driver_id':'threshold',
    'pass_id':'total_users_at_threshold',
    'redmine_id':'true_positives'
})

TOTAL_POPULATION = df_me['total_users_at_threshold'].sum()
TOTAL_POSITIVES = df_me['true_positives'].sum()
TOTAL_NEGATIVES = TOTAL_POPULATION - TOTAL_POSITIVES

df_me['TP'] = df_me['true_positives']
df_me['FN'] = TOTAL_POSITIVES - df_me['TP'] 
df_me['FP'] = df_me['total_users_at_threshold'] - df_me['TP'] 
df_me['TN'] = TOTAL_NEGATIVES - df_me['FP'] 


df_me['Recall'] = df_me['TP'] / TOTAL_POSITIVES * 100
df_me['Precision'] = df_me['TP'] / (df_me['TP'] + df_me['FP']) * 100
df_me['FPR'] = df_me['FP'] / TOTAL_NEGATIVES * 100
df_me['FNR'] = df_me['FN'] / TOTAL_POSITIVES * 100

df_me['F1_Score'] = 2 * (df_me['Precision'] * df_me['Recall']) / (df_me['Precision'] + df_me['Recall'])

df_me
# Out:
#     threshold  total_users_at_threshold  true_positives  TP  FN     FP     TN  Recall  Precision     FPR      FNR  F1_Score
# 0           1                     53914              32  32  22  53882   7638 59.2593     0.0594 87.5845  40.7407    0.1186
# 1           2                      5886               9   9  45   5877  55643 16.6667     0.1529  9.5530  83.3333    0.3030
# 2           3                      1180               2   2  52   1178  60342  3.7037     0.1695  1.9148  96.2963    0.3241
# 3           4                       337               1   1  53    336  61184  1.8519     0.2967  0.5462  98.1481    0.5115
# 4           5                       125               3   3  51    122  61398  5.5556     2.4000  0.1983  94.4444    3.3520
# 5           6                        63               3   3  51     60  61460  5.5556     4.7619  0.0975  94.4444    5.1282
# 6           7                        23               2   2  52     21  61499  3.7037     8.6957  0.0341  96.2963    5.1948
# 7           8                         6               0   0  54      6  61514  0.0000     0.0000  0.0098 100.0000       NaN
# 8           9                        12               0   0  54     12  61508  0.0000     0.0000  0.0195 100.0000       NaN
# 9          10                         9               0   0  54      9  61511  0.0000     0.0000  0.0146 100.0000       NaN
# 10         11                         3               0   0  54      3  61517  0.0000     0.0000  0.0049 100.0000       NaN
# 11         12                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN
# 12         13                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN
# 13         14                         2               0   0  54      2  61518  0.0000     0.0000  0.0033 100.0000       NaN
# 14         15                         2               0   0  54      2  61518  0.0000     0.0000  0.0033 100.0000       NaN
# 15         16                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN
# 16         17                         3               0   0  54      3  61517  0.0000     0.0000  0.0049 100.0000       NaN
# 17         18                         2               1   1  53      1  61519  1.8519    50.0000  0.0016  98.1481    3.5714
# 18         20                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN
# 19         22                         1               1   1  53      0  61520  1.8519   100.0000  0.0000  98.1481    3.6364
# 20         32                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN
# 21         55                         1               0   0  54      1  61519  0.0000     0.0000  0.0016 100.0000       NaN

# %%
df_res['sorted_tags'] = df_res['tags_list'].apply(lambda row: sorted(row))

df_res['sorted_tags'] = df_res['sorted_tags'].astype(str)

df_res.query("sorted_tags != ['List']").groupby('sorted_tags', as_index=False)[['driver_id', 'pass_id', 'redmine_id']].nunique().sort_values('redmine_id', ascending=False).head(10)\
    .rename(columns={
        'driver_id':'drivers',
        'pass_id':'reports',
        'redmine_id':'incidents',
    })
# Out:
#                                             sorted_tags  drivers  reports  incidents
# 118                             ['suspicious_activity']     4059     4666         25
# 119                                                  []     2196     3849         15
# 95                       ['long_distance', 'low_price']     5102    12834         11
# 111                                       ['low_price']    13313    29261          7
# 86                     ['drugs', 'suspicious_activity']      197      226          7
# 87                                            ['drugs']      929     1253          5
# 117                                  ['sexual_content']      844      978          4
# 115                                           ['other']     1279     1473          4
# 84   ['drugs', 'sexual_content', 'suspicious_activity']      132      193          2
# 114                    ['other', 'suspicious_activity']      126      132          2

# %%
df_exploded = df_res.explode('tags_list')

df_exploded.query("tags_list != 'List'").groupby('tags_list', as_index=False)[['driver_id', 'pass_id', 'redmine_id']].nunique().sort_values('redmine_id', ascending=False)
# Out:
#              tags_list  driver_id  pass_id  redmine_id
# 6  suspicious_activity       6489     9510          41
# 2        long_distance       7095    17045          21
# 3            low_price      17749    42787          21
# 1                drugs       2477     3988          16
# 4                other       2566     4020          10
# 0        advertisement       1677     2602           9
# 5       sexual_content       2236     3424           6

# %%
df_exploded[df_exploded['tags_list']=='suspicious_activity']['text'].unique()
# Out:
# array(['"ladrones modo operativos "', '""',
#        '"estafa Robo , destino siempre roban "', '"es un estafador"',
#        '"roban"', '"raro sube y baja el precio "',
#        '"es para llevar drogas "', '"fake rided"', '"robo"',
#        '"fake account "', '"orderan palsu"', '"Orderan Fiktif "',
#        '"orderan fiktif"',
#        '"es una estafa cierren le la cuenta a este animal "',
#        '"handa Pani uthaudai na"', '"membuat orderan palsu "', '"penipu"',
#        '"fake ride "', '"robo intento de hurto"',
#        '"la ves pasada me estafaron me quitaron 180.000 de mi cuenta "',
#        '"fake ID laga raha hai"', '"facke ride "', '"estafadores "',
#        '"posible estafa"', '"sospechoso "',
#        '"customer froad hai ismein driver ko Gali Di Hai"',
#        '"Estafadores "', '"estafa"',
#        '"pone viajes para robar la gente se llama Ronald "',
#        '"estafador pide dinero por nequi el maldito perro deberían tener más control con ese tipo de ratas "',
#        '"es un cliente falso"',
#        '"o cliente fica colocando corrida fake "',
#        '"отменил когда уже подехал специально"', '"son estafadores "',
#        '"el usuario tiene pocos servicios "',
#        '"esa oferta es una estafa cierren esa cuenta de mierda que se pudra ese hp y miserable estafador disculpe mi grosería pero seguro es un animal de ser humano no merece respeto"',
#        '"lambucia"', '"acepta y cancela "', '"viaje con intento de robo"',
#        '"orderan palsu yang tidak bisa di ajak jalan "',
#        '"este usuario está estafando a la gente "', '"fake ride"',
#        '"es una posible estafa"', '"fake"',
#        '"ya kohti ma ki bachi APNA dia hoa rat par bi nahi uta rahi 15 minat ho gya "',
#        '"llegue al punto de recojo y cancelo el pedido , en un lugar donde habían varios sujetos de mal vivir "',
#        '"Perfil falso "', '"just teasing the rider fake"', '"ladrones "',
#        '"oq acontece"', '"es una estafa tengan cuidado son ratas "',
#        '"просит перевести наркотики "', '"paquete sospechoso "',
#        '"fake fake fake"',
#        '"presunta estafa pide pagar antes a un numero que iba a dar  sin antes estar presebte en el lugar"',
#        '"fake person "', '"cliente con fraude"',
#        '"es un ladrón  y busca robar los indriver "',
#        '"akun fake cuma buat orderan fake mengganggu"',
#        '"robo, fraude, estafa "', '" "', '"puto"',
#        '"no entiendo que ofrece sr"', '"z"', '"pedidos de broma "',
#        '"scammer "', '"doesn\'t respond "', '"f"', '"order palsu"',
#        '"todo dia essa pa palhaçada desse usuário todo dia a corrida dele oferecendo o preço caro e quer o chá que o motorista garoto de programa"',
#        '"scam fake booking "', '"gohj"', '"jelema anjing"',
#        '"order mengulang"',
#        '"order terus dengan beda harga , ini order palsu"', '"jahil "',
#        '"fake rights"', '"bloke kary "',
#        '"iska account block Karen fake Rider"', '"Gusti"',
#        '"khanki chele"', '"false order "',
#        '"selalu melakukan orderan palsu"', '"fictitious orders"',
#        '"es diferente al usuario"', '"baar bar cancel kar raha hai "',
#        '"meri ride book kar k mn location pe ayaa or es ne cancel kar dia"',
#        '"rechaza ofertas"',
#        '"Ele é um homossexual coloca o número do zap pra fazer propostas de programa"',
#        '"pelor"',
#        '"sir ye bar bar ride krwata hai accept kr k cancel kr deta hai"',
#        '"не вышел. играют водителей "', '"6"',
#        '"sigues pidiendo servicio y no sale ni responde las llamadas "',
#        '"mucho via"', '"complaint complain complaint"',
#        '"passenger can\'t to go"', '"akun tembak"',
#        '"orderan fiktif tolong di tindak"', '"Order palsu tolong stop"',
#        '"cina barua Babi sial "', '"que le pasa"', '"order fiktif "',
#        '"bermain order,,, tolong di blokir akun nya"', '"pesetera h"',
#        '"Indonesia barua "',
#        '"عماله تطلب وتلغي تلغي للكابتن الي مرضاش يديهافلوس.   دي نصابه "',
#        '"tài xế đặt cuốc xe giả."', '"fake booking "',
#        '"He utters obscene words "',
#        '"nuevamente sigue la propuesta, acepto su precio pero me rechaza... creo que busca víctimas "',
#        '"permintaan transportasi berulang terus menerus. tolong tindaki akun ini. karenah merugikan driver. mohon bantuannya."',
#        '"фейк заказ висит 17 мин"', '"cik atuh ulah tetembakan "',
#        '"order fijtif"', '"fraudulent activity "',
#        '"penumpang berulah penumpang udah lama pesan tapi tidak satupun yang di terima drivernya "',
#        '"akun fiktif "', '"complain complain"',
#        '"cancel danborder mulu ke tempat tujuan yang berbeda-beda"',
#        '"order fiktif"', '"parah"', '"dice que son 10 personas "',
#        '"golpe ladrão "',
#        '"he is doing suspicious activity and doing fake rides kindly indrive take action against his account "',
#        '"no entiendo cómo la aplicación deja poner un precio de estos por más de 15 km ni a $1000 el kilómetro y aparte el vehículo se devuelve vacío con el conductor... como que la aplicación solo piensa en el usuario y el conductor a un lado"',
#        '"trae un arma"', '"pelor "', '"barua sial musibat haram jadah "',
#        '"order fitif"', '"FIKTIF"', '"cancelación "',
#        '"está diciendo que se le escriba al privado "',
#        '"solicitud sospechosa "', '"pone y cancela las solicitudes "',
#        '"esa persona siempre, solicita pero no concreta nada.  creo que es para drogas o algo así "',
#        '"No acepta las solicitudes y aceptó su precio que oferta"',
#        '"Client makaynch"', '"jugando con la plataforma "',
#        '"acepto su tarifa propuesta pero me cancela y en la lista de carreras sigue vigente su solicitud."',
#        '"a cancelado otras veces "', '"بيتناك"',
#        '"hacen llegar y cancela "', '"cancela mucho discrimina"',
#        '"poca calificacion"', '"fake  block pleas"',
#        '"no lo se! parece falso! está jugando con las solicitudes "',
#        '"passageira solicita carro com criança recém nascido e quer fazer viagem sem segurança "',
#        '"fake order "',
#        '"pedido Falso no acepta por el precio que ellos mismo ofrecen "',
#        '"Usuario alto tiego Asalto al conductor"', '"Posible asalto"',
#        '"hantoma tfalya"',
#        '"Solicita Viaje, no acepta y coloca su numero en la descripción para pedir sexo"',
#        '"lleva 3 minutos y no se decide por algún conductor de indriver"',
#        '"стояло 600тнг потом поста"', '"fake "',
#        '"too much nude and sex advertising "', '"pasajero sospechoso "',
#        '"pasajero no paga peaje"', '"driver banyak yg nembak ini"',
#        '"miserable muerta de hambre "',
#        '"he/she did not accept my request 2 times"',
#        '"barrio peligroso "', '"bar bar dherai "', '"suspicious"',
#        '"fake booking scammer alert "', '"es pedido falso"',
#        '"aceitei pelo valor e a mesma não aceitou"', '"orderan fiktif "',
#        '"usuario pidiendo viajes falsos"', '"Fake booking"', '"paga pco"',
#        '"too much sex advertising "',
#        '"no pone el precio justo y ala hija su puta madre se le hace caro "',
#        '"rate bahut kam hai"',
#        '"this person accept the request then cancel it he made 7 ride and cancel then please take action against him "',
#        '"hace ir ha esperarle y no sale le quieren ver la cara de pendejo.  por favor suspender esa cuenta con urgencia. "',
#        '"ausente "', '"taxieuuuur brakkage"',
#        '"he just get funny and spend our time"', '"ko block Karen bhai"',
#        '"block karo isko"', '"fraud  and bullying "', '"Vende drogas"',
#        '"nombre de usuario no real "', '"rating 1,0"', '"xx"', '"xxx"',
#        '"não aceita e fica alimentando o valor"',
#        '"cheguei no local ele cancelou e não aceitou de novo e tá meia hora chamando no app mais não aceita nenhum motorista "',
#        '"si no va a realizar el viaje cancele, o está buscando auto para robar?"',
#        '"orderan palsu .. bikin orang susah"', '"متلعلب"',
#        '"sigue pidiendo el servicio está jugando no quiere aceptar el servicio "',
#        '"sigue pidiendo el servicio y no acepta yo estado cerca "',
#        '"ye Behan jod Jan boj kar tang kar raha h "',
#        '"suspecious person"', '"aceito a corrida , mas não aceita"',
#        '"disterbens"',
#        '"llegando a la ubicación están 4 sujetos pidiendo dinero para dejarte entrar a la calle, llegando a la ubicación te cancela y para salir de la calle te vuelven a pedir dinero amenazando que te quitan tus pertenencias. "',
#        '"pide. y cancela "', '"كابتن وبيعمل رحلات وهميه"',
#        '"itne Jana Nahin Hai fake right Kar Raha Hai Isko 3 minut Mein rate De chuka hun"',
#        '"fiktiv"', '"playing around some idot fella"', '"fack raid "',
#        '"380 takay accept kore pore message diye bole 270 takay na gele cancel kore dibe abong pore cancel kore"',
#        '"الواد ده وكلمته ولغى"', '"tembak orderan mengganggu orderan"',
#        '"pide el servicio y no lo acepta"', '"pedido falso"',
#        '"pornografia infantil "', '"vários endereços diferentes "',
#        '"manipulación de los precios de indrai"',
#        '"she book rides and talk very roughly and rudely and cancels ride"',
#        '"she talks rudely after accepting rides and cancels it afterwords"',
#        '"bloquear está cuenta "',
#        '"Сколько можно переписываться !!!!с людьми которые хотят ехать, чтобы ещё и водитель добавил свои средства чтобы доехать с точки а в точку б, сделайте фильтр , выбор расторжения,и стоимость за км,Вы нас за людей не считаете!!!сидеть смотреть в этот бред который предлагают."',
#        '"pesetero miserable "', '"área de risco"',
#        '"سعر عالي جدا علي مشوار قصير يتلاعب "',
#        '"ya fak raid dal Raha hy "', '"solicitação falsa "',
#        '"pedido falso son rateros "', '"no coge las carreras"',
#        '"Jugando con la app "', '"acepta servicios y los cancela "',
#        '"falta de respeto "',
#        '"cliente posible estafador..bloquear cuenta"', '"j"',
#        '"penipuan "', '"abusivooooooo"', '"bloqueen n"', '"fake account"',
#        '"estafa "',
#        '"he putting a lot fare accept then not receiving call"',
#        '"fake order"', '"solicitan los viajes y no los aceptan "',
#        '"muy bajo el precip "', '"drugs "',
#        '"ela chama e na frente olhando pra gente cancelar a corrida"',
#        '"fazool ma ride book kertha hy just joking "', '"hueso "',
#        '"cliente fazendo graça no aplicativo "',
#        '"مش عايز يدفع الكارته "', '"opik"', '"delincuentes "',
#        '"تلاعب بالاسعار لادني مستوي"',
#        '"chama o aplicativo, quando chegar, ela cancelar e pede por um valor menor"',
#        '"penipuan"', '"алкаш"', '"pide un carro sub "', '"taxieur"',
#        '"sin foto de perfil "', '"no responde"',
#        '"não aceita corrida , corrida fake"',
#        '"driver ojeg online membuat orderan fiktif"', '"baratero "',
#        '"chamada falsa "', '"fake Ride"',
#        '"Tolong Diblokir soalnya sudah meresahkan sekali akun tersebut "',
#        '"sangat mengganggu tolong jangan di tampilkan lagi"',
#        '"عميل ابن شرموطه"', '"lisa"', '"muerta de hambre "',
#        '"muerta de ambre"',
#        '"sudah sering membuat notif orderan ,,,tetap selalu sudah diterima ,,,sangat mengganggu kerja orang"',
#        '"pide y pide servicios y uno la acepta  y ella rechaza"',
#        '"que falta de respeto "', '"cancelou sem motivo"',
#        '"كابتن قليل الادب  بيعمل رحلات وهميه بيزلول الكباتن"',
#        '"demasiado bajo el precio por favor "', '"و"', '"piktif"',
#        '"driver berpura pura pesan orderan sebagai penumpang melakukan order fiktif tolong di bantu blokir admin."',
#        '"cliente solicita y cancela"', '"تسعيره منخفضه جدا"',
#        '"miserable "', '"no sean tan barateros con los servicios "',
#        '"cambiar precio verificar distancia de pago y cambiar el precio de la principal causa de la principal causa "',
#        '"block "',
#        '"wna barsa quiere recorrer todo Santiago por 5 lucas "',
#        '"lo Paris "', '"very poor "', '"too much nude activity "',
#        '"el pasajero está drogado"', '"ya a pedido y cancela"', '"idiot"',
#        '"Actividad sospechosa"',
#        '"الراكب يتلاعب بخوارزمات الابلكيشن ما يؤدي إلى نقص فى السعر"',
#        '"lladron "', '"fake booki5"', '"just playing with the booking"',
#        '"solicita y cancela muy seguido"', '"هكر وحرامي "',
#        '"this person is a scammer "', '"perfil fake"',
#        '"presunto ladrón "',
#        '"tolong tindak lanjuti akun tersebut karena sudah melakukan order fiktif "',
#        '"no acepta su propia tarifa "', '"drive"',
#        '"cambiar precio verificar distancia de "', '"report cuenta faek"',
#        '"ahora está pidiendo una persona que es mujer la misma dirección quieren robar"',
#        '"usuario cancela solicitud una vez llega el chófer  al punto de encuentro"',
#        '"ya bhen chod ka bcha Kafi der sy fake ride dal rha ha bhen chod "',
#        '"order viktif membawa sajam"',
#        '"orderan fiktif, mengganggudriver"', '"ram nah never mancha"',
#        '"Venta de droga "', '"relajando "', '"Essa lisa de maré de Dedé"',
#        '"كابتن يقوم بعمل طلبات وهميه"', '"choro"',
#        '"elprwsio muy bajo sobre el kilomehravw "',
#        '"calificación baja "',
#        '"ha pedido diferentes viajes de diferentes puntos "',
#        '"tava nu na rua"',
#        '"no tiene foto de perfil y tiene muy mala calificación "', '"t"',
#        '"tiene rato pidiendo y no agarra a ningún conductor"',
#        '"no paga"', '"este usuario está jugando con el precio "',
#        '"revisar , muy raro montos a poner "', '"fake rider"',
#        '"pelor tindakan lah min..bikin susah carik rezeki"',
#        '"calificación muy baja "',
#        '"tiene la solicitus 14 minutos y no hay cuando acepte el viaje "',
#        '"spam"', '"edot jarga tidak manusiawi"', '"spam orderan fiktif "',
#        '"sering melakukan orderan fiktif"', '"precio miserable"', '"v"',
#        '"está pidiendo viaje y no acepta ninguna oferta"',
#        '"Pide sexo bloquear el perfil"', '"muy bajo el precio "',
#        '"no sean miserables "', '"más peajes..."', '"tembakan"',
#        '"es demasiado lejos y quiere pagar el kilómetro a solo 50 centavos está loca o que?"',
#        '"faux courses "', '"order Fiktif ini. dari td ngorder trs."',
#        '"es una perra "', '"not picking "', '"penipu "',
#        '"no sea barateros con los servicios "',
#        '"Es una prostituta , quiere robar "', '"permainkan orderan "',
#        '"randi ko ban"', '"usuario peligroso "', '"delincuente "',
#        '"mieserable"', '"muy poco pal ida 6 vuel5a"', '"está jugando "',
#        '"es acosador"', '"غير محترم"', '"driver usil"',
#        '"sering melakukan order tapi tidak berangkat"', '"fake rider "',
#        '"fiktif"', '"дура"', '"puta gente pobre"', '"tarifa no adecuada"',
#        '"yg"', '"Usuario no responde "',
#        '"tiene calificacion demasiado baja"',
#        '"Nunca acepta ninguna oferta solo pública el viaje"',
#        '"como que esta pendiente te de robar ya que pide y pide y no acepta y ha cambiado de dirección en reiteradas ocasiones "',
#        '"заказ принимает потом отменяет"', '"randi ko xoro "', '"عرص"',
#        '"no acepta ningún carro"', '"robp"',
#        '"muita proposta e nenhuma retorno"', '"fake hai"',
#        '"pide el servicio y"', '"Order terus menerus tanpa pick driver"',
#        '"����"', '"cancel the my ride this person was scammer"',
#        '"mempermainkan draiver"', '"spam orderan fiktif"',
#        '"perfil no verificado "', '"1 ghante se pareshan"', '"fiktip"',
#        '"orderan palsu "', '"orderan fiktif (orderan tembak)"',
#        '"cancela el viajr frecuentemente"', '"pasajero acepta y cancela"',
#        '"block kro is ko"',
#        '"ya estaba llegando estaba yo cerca del pedido y canceló y volvió a pedir un indrive "',
#        '"con menores de edad "'], dtype=object)
